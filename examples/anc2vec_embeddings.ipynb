# %% [markdown]
# # Pre-trained Anc2Vec embeddings

# %% [markdown]
# ## Install `anc2vec` package

# %%
# !pip3 install -U pip > /dev/null
# !pip3 install -U "anc2vec @ git+https://github.com/aedera/anc2vec.git" > /dev/null
# Out:
#   Running command git clone -q https://github.com/aedera/anc2vec.git /tmp/pip-install-4e5ybxr1/anc2vec_23b5dd185ec44dd794186abfd12569bc

# %% [markdown]
# ## Load embeddings

# %%
import anc2vec
embeds = anc2vec.get_embeddings()

# %% [markdown]
# ## Retriving embeddings
#
# To retrieve the embedding of GO:0001780, we first need to obtain its index in the embedding matrix.

# %%
row_id = embeds['term2index']['GO:0001780'] # recover index
embeds['embeddings'][row_id]
# Out:
# array([ 0.55203265, -0.23133564,  0.1983797 , -0.3251996 ,  0.20564775,
#        -0.32133245, -0.25364587, -0.16675541, -0.46832997, -0.40702957,
#        -0.0873375 , -0.31255123,  0.21853212, -0.23443316,  0.29934332,
#        -0.28383982, -0.41982067, -0.21407397, -0.36336198, -0.21446162,
#         0.41194695, -0.25694677,  0.20185658, -0.11861248, -0.2565916 ,
#        -0.36906996, -0.39008674, -0.3004449 , -0.35822818, -0.37389165,
#         0.2137229 , -0.37333834,  0.14497578, -0.23230654,  0.39553115,
#         0.4735052 ,  0.36913154, -0.16290289,  0.2194309 , -0.30572593,
#         0.26810315, -0.17395245,  0.3182136 , -0.12777388,  0.32668477,
#        -0.3070236 ,  0.3788477 , -0.25539076, -0.2754244 ,  0.3055507 ,
#        -0.3344264 ,  0.3904205 , -0.21383607,  0.19237018,  0.24540633,
#        -0.2503321 , -0.27165422, -0.3038103 ,  0.1473993 ,  0.2575735 ,
#        -0.3533151 , -0.27241638, -0.24932317, -0.21835163,  0.22360924,
#        -0.2705398 ,  0.18488185, -0.3506352 , -0.21811526, -0.4199195 ,
#         0.20644702,  0.36297655,  0.392916  ,  0.15100072,  0.44224554,
#         0.37067226, -0.3272614 , -0.21693765, -0.28504354,  0.1531946 ,
#        -0.02209148,  0.39652172, -0.27309793,  0.14407489,  0.43211856,
#        -0.10782488,  0.40077034, -0.2778314 ,  0.1523993 , -0.05631523,
#         0.23218712, -0.26930737, -0.23233101,  0.38441855, -0.26035944,
#        -0.21449101,  0.43355763, -0.37792093,  0.27351418,  0.6810427 ,
#        -0.28312585,  0.30380455,  0.22994627,  0.28240788, -0.23584595,
#        -0.25523117,  0.1743649 ,  0.18484096,  0.35965666, -0.22726637,
#         0.18326205,  0.20052469,  0.15670885,  0.18289927,  0.3389342 ,
#         0.16550113, -0.22625165, -0.29885185, -0.25649163,  0.35527736,
#         0.18380488, -0.34883714,  0.22741222, -0.40878412,  0.34404975,
#        -0.28970858,  0.2050755 ,  0.2584193 ,  0.39229858,  0.479956  ,
#        -0.25458694, -0.3140787 ,  0.3723085 , -0.24657208,  0.12822485,
#        -0.39831015,  0.23075983,  0.32658416, -0.19494995, -0.32288527,
#        -0.2243172 , -0.29983276, -0.22898968,  0.16617514, -0.06680927,
#        -0.36715445, -0.32420412, -0.38286498,  0.4461922 , -0.2431454 ,
#        -0.33862695,  0.26800063, -0.25150442, -0.39733315, -0.19981006,
#         0.24072956, -0.22914447,  0.23811895, -0.45725778, -0.22380288,
#        -0.16144791, -0.07488008, -0.191301  ,  0.2781139 ,  0.33735192,
#        -0.37345156,  0.35152853, -0.2214171 ,  0.33167428, -0.1475042 ,
#         0.2537345 , -0.30710378, -0.28027663, -0.3450159 ,  0.1140846 ,
#        -0.30178562, -0.30176443,  0.2460824 , -0.35609406, -0.10120773,
#        -0.24593459,  0.39973947, -0.35996372, -0.38002947,  0.32256082,
#        -0.41098195,  0.19838189, -0.30278823, -0.25028783, -0.38092571,
#        -0.29757708, -0.33143485, -0.31099185,  0.24465033, -0.25458524,
#        -0.24525951, -0.366758  , -0.04628978,  0.29378492,  0.31249675],
#       dtype=float32)
